# %%
pip install geopy pandas
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (2.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy) (2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from math import radians, cos, sin, sqrt, atan2
from scipy.spatial import KDTree
from geopy.geocoders import GoogleV3
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import time

# %%
# CSV 파일을 읽어옵니다
train_df =pd.read_csv('/content/drive/MyDrive/ML4_adv/train.csv')

# Load the 최종위도경도.csv file
final_lat_lon_df = pd.read_csv('/content/drive/MyDrive/ML4_adv/최종위도경도.csv')

#subway_feature_df = pd.read_csv('/content/drive/MyDrive/ML4_adv/subway_feature.csv')
# Out:
# <ipython-input-50-c55dcd22d085>:2: DtypeWarning: Columns (16,17,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df =pd.read_csv('/content/drive/MyDrive/ML4_adv/train.csv')

# %%
# Generate the address column, keeping the missing values in '번지' as they are
train_df['address'] = train_df['시군구'] + ' ' + train_df['번지'].astype(str)

# Merge the dataframes on the address column
merged_df = pd.merge(train_df, final_lat_lon_df, on='address', how='left')

# Save the merged result to a new CSV file
merged_file_path = '/content/drive/MyDrive/ML4_adv/merged_train.csv'
merged_df.to_csv(merged_file_path, index=False)

print(f"Merged file saved to: {merged_file_path}")
# Out:
# Merged file saved to: /content/drive/MyDrive/ML4_adv/merged_train.csv

# %%
merged_df.drop(columns=['좌표X', '좌표Y'], inplace=True)

# Save the updated dataframe to a new CSV file
updated_file_path = '/content/drive/MyDrive/ML4_adv/updated_merged_train.csv'
merged_df.to_csv(updated_file_path, index=False)

# %%
# CSV 파일 읽기
train_df = pd.read_csv('/content/drive/MyDrive/ML4_adv/train.csv')

# '시군구'와 '지번' 컬럼을 결합하여 'address' 컬럼 생성
train_df['address'] = train_df['시군구'].astype(str) + ' ' + train_df['번지'].astype(str)

# 중복된 주소 제거
unique_addresses_df = train_df[['address']].drop_duplicates()

# 결과를 새로운 CSV 파일로 저장
unique_addresses_df.to_csv('/content/drive/MyDrive/ML4_adv/unique_addresses.csv', index=False)

# 결과 출력 (선택 사항)
print(unique_addresses_df.head().unique)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-20-aa2e11b67e5c> in <cell line: 2>()
#       1 # CSV 파일 읽기
# ----> 2 train_df = pd.read_csv('/content/drive/MyDrive/ML4_adv/train.csv')
#       3
#       4 # '시군구'와 '지번' 컬럼을 결합하여 'address' 컬럼 생성
#       5 train_df['address'] = train_df['시군구'].astype(str) + ' ' + train_df['번지'].astype(str)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     581
#     582     with parser:
# --> 583         return parser.read(nrows)
#     584
#     585
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1702                     columns,
#    1703                     col_dict,
# -> 1704                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1705                     nrows
#    1706                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
unique_addresses_df.value_counts()
# Out:
# address
# 서울특별시 강남구 개포동 1164-12    1
# 서울특별시 서초구 잠원동 71-12      1
# 서울특별시 서초구 잠원동 67-1       1
# 서울특별시 서초구 잠원동 67-2       1
# 서울특별시 서초구 잠원동 70         1
#                         ..
# 서울특별시 구로구 구로동 792-58     1
# 서울특별시 구로구 구로동 792-54     1
# 서울특별시 구로구 구로동 792-50     1
# 서울특별시 구로구 구로동 792-42     1
# 서울특별시 중랑구 중화동 454        1
# Name: count, Length: 8943, dtype: int64

# %%
# Google API 키 설정
google_api_key = 'AIzaSyAjpnK396O_8o7WEVOzG6b9xUEr4CNmMl8'

# CSV 파일 읽기
addresses_df = pd.read_csv('/content/drive/MyDrive/ML4_adv/unique_addresses.csv')

# 인덱스 리스트
indices = [29, 230, 312, 415, 648, 647, 1221, 1586, 1775, 2056, 2152, 2348, 2423, 3030, 3109, 3163, 3125, 3415, 3579, 3647, 3851, 3880, 3977, 3955, 4053, 4109, 4106, 4087, 4135, 4281, 4280, 4252, 4388, 4466, 5141, 5413, 5498, 5640, 5805, 5862, 5871, 5874, 5875, 6183, 6257, 6264, 6273, 6263, 6281, 6283, 6278, 6296, 6327, 6336, 6311, 6342, 6335, 6319, 6360, 6308, 6334, 6366, 6365, 6364, 6277, 6397, 6538, 6611, 6645, 6618, 6608, 6662, 6676, 6654, 6691, 6648, 6692, 6686, 6688, 6766, 6741, 6762, 6756, 6728, 6760, 6811, 6789, 6771, 6763, 6785, 6788, 6697, 6830, 6864, 6853, 6742, 6929, 7002, 6992, 7012, 7242, 7276, 7260, 7321, 7347, 7349, 7350, 7364, 7341, 7365, 7377, 7394, 7384, 7400, 7444, 7443, 7503, 7526, 7477, 7568, 7629, 7690, 7697, 7809, 7798, 7917, 7922, 8138, 8218, 8459, 8540, 8539, 8591, 8568, 8606, 8569, 8609, 8599, 8676, 8771, 8775, 8780, 8817, 8770, 8773, 8788, 8677, 8807, 8781, 8783, 8833, 8877, 8868, 8876, 8826, 8924, 8782, 8928, 8941, 8912, 8929, 8943, 8923, 8935, 8942, 8931, 8902, 8932]
  # 실제 인덱스 리스트를 여기에 사용하십시오
indices = [i-1 for i in indices]
# 유효한 주소만 필터링
valid_addresses_df = addresses_df.loc[indices]


print(valid_addresses_df.head())
# Out:
#                  address
# 28     서울특별시 강남구 개포동 656
# 229   서울특별시 강남구 삼성동 19-4
# 311    서울특별시 강남구 역삼동 712
# 414  서울특별시 강남구 일원동 690-1
# 647    서울특별시 강동구 상일동 124

# %%
# 지오코딩 설정
geolocator = GoogleV3(api_key=google_api_key)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# 주소를 위도와 경도로 변환하는 함수
def geocode_address(address):
    try:
        location = geocode(address)
        if location:
            return location.latitude, location.longitude
        else:
            print(f"No location found for address: {address}")
            return None, None
    except Exception as e:
        print(f"Error geocoding {address}: {e}")
        return None, None

# 행별로 조회하면서 주소의 마지막이 'nan'인 경우 제거하고 지오코딩 수행
latitudes = []
longitudes = []

for index, row in valid_addresses_df.iterrows():
    address = row['address']
    if pd.isna(address):
        latitudes.append(None)
        longitudes.append(None)
    else:
        # 주소의 마지막이 'nan'인 경우 제거
        address = ' '.join([part for part in address.split() if part != 'nan'])
        latitude, longitude = geocode_address(address)
        latitudes.append(latitude)
        longitudes.append(longitude)
        print(f"Address: {address}")
        print(f"Latitude: {latitude}, Longitude: {longitude}\n")

# 결과를 데이터프레임에 추가
valid_addresses_df['Latitude'] = latitudes
valid_addresses_df['Longitude'] = longitudes

# 기존 데이터프레임에 병합
addresses_df.update(valid_addresses_df)

# 결과를 새로운 CSV 파일로 저장
addresses_df.to_csv('/content/drive/MyDrive/ML4_adv/updated_addresses.csv', index=False)

# 결과 출력
print(valid_addresses_df)
# Out:
# Address: 서울특별시 강남구 개포동 656
# Latitude: 37.4785667, Longitude: 127.0555862
#
# Address: 서울특별시 강남구 삼성동 19-4
# Latitude: 37.5175246, Longitude: 127.0499786
#
# Address: 서울특별시 강남구 역삼동 712
# Latitude: 37.50163440000001, Longitude: 127.0455277
#
# Address: 서울특별시 강남구 일원동 690-1
# Latitude: 37.48997, Longitude: 127.0774559
#
# Address: 서울특별시 강동구 상일동 124
# Latitude: 37.5512348, Longitude: 127.1721537
#
# Address: 서울특별시 강동구 상일동 134
# Latitude: 37.5511028, Longitude: 127.1696401
#
# Address: 서울특별시 강서구 염창동 275-5
# Latitude: 37.5499965, Longitude: 126.8673667
#
# Address: 서울특별시 관악구 신림동 1644
# Latitude: 37.4842295, Longitude: 126.9039076
#
# Address: 서울특별시 광진구 자양동 658-14
# Latitude: 37.5326098, Longitude: 127.0845012
#
# Address: 서울특별시 구로구 구로동 685-280
# Latitude: 37.4951408, Longitude: 126.8783443
#
# Address: 서울특별시 구로구 오류동 282
# Latitude: 37.4870738, Longitude: 126.832052
#
# Address: 서울특별시 노원구 공릉동 230
# Latitude: 37.626375, Longitude: 127.0830489
#
# Address: 서울특별시 노원구 상계동 109-5
# Latitude: 37.6689012, Longitude: 127.0788846
#
# Address: 서울특별시 동작구 상도동 324
# Latitude: 37.499096, Longitude: 126.9298485
#
# Address: 서울특별시 동작구 신대방동 729-24
# Latitude: 37.4926743, Longitude: 126.9171843
#
# Address: 서울특별시 마포구 아현동 800
# Latitude: 37.5544849, Longitude: 126.9562273
#
# Address: 서울특별시 마포구 공덕동 800
# Latitude: 37.54811249999999, Longitude: 126.9549965
#
# Address: 서울특별시 서대문구 북아현동 149
# Latitude: 37.56241680000001, Longitude: 126.9543856
#
# Address: 서울특별시 서초구 내곡동
# Latitude: 37.4550628, Longitude: 127.0695079
#
# Address: 서울특별시 서초구 반포동 32-8
# Latitude: 37.5022658, Longitude: 127.0117911
#
# Address: 서울특별시 서초구 신원동 690
# Latitude: 37.4441742, Longitude: 127.062145
#
# Address: 서울특별시 서초구 서초동 1335
# Latitude: 37.4890871, Longitude: 127.0261778
#
# Address: 서울특별시 서초구 신원동
# Latitude: 37.4441742, Longitude: 127.062145
#
# Address: 서울특별시 서초구 서초동 1336
# Latitude: 37.4783695, Longitude: 127.0144784
#
# Address: 서울특별시 서초구 잠원동 74
# Latitude: 37.5087872, Longitude: 127.0022868
#
# Address: 서울특별시 성동구 금호동2가 1331
# Latitude: 37.5530275, Longitude: 127.020416
#
# Address: 서울특별시 성동구 금호동1가 280
# Latitude: 37.553569, Longitude: 127.0249849
#
# Address: 서울특별시 서초구 잠원동 74-1
# Latitude: 37.50738279999999, Longitude: 127.0029924
#
# Address: 서울특별시 성동구 상왕십리동 1070
# Latitude: 37.56610999999999, Longitude: 127.0276467
#
# Address: 서울특별시 성북구 동소문동7가 261
# Latitude: 37.5963265, Longitude: 127.0141985
#
# Address: 서울특별시 성북구 동소문동7가 280
# Latitude: 37.5963265, Longitude: 127.0141985
#
# Address: 서울특별시 성북구 길음동 973-2
# Latitude: 37.6080317, Longitude: 127.0257527
#
# Address: 서울특별시 성북구 하월곡동 949
# Latitude: 37.6046451, Longitude: 127.0393912
#
# Address: 서울특별시 송파구 거여동 199-2
# Latitude: 37.4943636, Longitude: 127.1481279
#
# Address: 서울특별시 영등포구 당산동5가 4-13
# Latitude: 37.5312144, Longitude: 126.9001679
#
# Address: 서울특별시 용산구 이태원동 669
# Latitude: 37.5385051, Longitude: 126.9925224
#
# Address: 서울특별시 용산구 효창동 3-197
# Latitude: 37.5475034, Longitude: 126.9629106
#
# Address: 서울특별시 은평구 수색동 223-28
# Latitude: 37.5861575, Longitude: 126.8933245
#
# Address: 서울특별시 은평구 증산동 213-20
# Latitude: 37.5810087, Longitude: 126.9027162
#
# Address: 서울특별시 중구 만리동2가 176-1
# Latitude: 37.5540378, Longitude: 126.9638626
#
# Address: 서울특별시 은평구 진관동 135
# Latitude: 37.6408009, Longitude: 126.9368069
#
# Address: 서울특별시 종로구 교남동 199
# Latitude: 37.5716359, Longitude: 126.9639041
#
# Address: 서울특별시 종로구 교남동 233
# Latitude: 37.5716359, Longitude: 126.9639041
#
# Address: 서울특별시 중랑구 상봉동 785
# Latitude: 37.5984717, Longitude: 127.0871082
#
# Address: 서울특별시 강남구 개포동 138
# Latitude: 37.4802905, Longitude: 127.0626272
#
# Address: 서울특별시 강남구 논현동 276
# Latitude: 37.5095247, Longitude: 127.038955
#
# Address: 서울특별시 강남구 대치동 612
# Latitude: 37.49575919999999, Longitude: 127.059333
#
# Address: 서울특별시 강남구 개포동 140
# Latitude: 37.4797385, Longitude: 127.0660782
#
# Address: 서울특별시 강남구 대치동 633-22
# Latitude: 37.4940684, Longitude: 127.0561082
#
# Address: 서울특별시 강남구 도곡동 893-2
# Latitude: 37.4880806, Longitude: 127.0394509
#
# Address: 서울특별시 강남구 대치동 610
# Latitude: 37.4991887, Longitude: 127.0633458
#
# Address: 서울특별시 강남구 삼성동 22
# Latitude: 37.51397499999999, Longitude: 127.0561274
#
# Address: 서울특별시 강남구 청담동 106-11
# Latitude: 37.5278347, Longitude: 127.05109
#
# Address: 서울특별시 강동구 고덕동 212
# Latitude: 37.5638217, Longitude: 127.1582312
#
# Address: 서울특별시 강남구 역삼동 709
# Latitude: 37.50258, Longitude: 127.0463139
#
# Address: 서울특별시 강동구 길동 43
# Latitude: 37.5424596, Longitude: 127.15031
#
# Address: 서울특별시 강동구 고덕동 220
# Latitude: 37.5638217, Longitude: 127.1582312
#
# Address: 서울특별시 강남구 일원동 690-2
# Latitude: 37.48997, Longitude: 127.0774559
#
# Address: 서울특별시 강동구 명일동 294
# Latitude: 37.5512602, Longitude: 127.1461342
#
# Address: 서울특별시 강남구 역삼동 711
# Latitude: 37.4994269, Longitude: 127.0446982
#
# Address: 서울특별시 강동구 고덕동 492
# Latitude: 37.5638217, Longitude: 127.1582312
#
# Address: 서울특별시 강동구 상일동 187
# Latitude: 37.5511028, Longitude: 127.1696401
#
# Address: 서울특별시 강동구 상일동 131
# Latitude: 37.5511028, Longitude: 127.1696401
#
# Address: 서울특별시 강동구 상일동 121
# Latitude: 37.5472666, Longitude: 127.1800274
#
# Address: 서울특별시 강남구 대치동 633
# Latitude: 37.4940684, Longitude: 127.0561082
#
# Address: 서울특별시 강서구 염창동 279-15
# Latitude: 37.5527315, Longitude: 126.8707482
#
# Address: 서울특별시 구로구 천왕동 292-10
# Latitude: 37.4808353, Longitude: 126.8398192
#
# Address: 서울특별시 동작구 상도동 36-1
# Latitude: 37.5079238, Longitude: 126.9517656
#
# Address: 서울특별시 마포구 용강동 18-2
# Latitude: 37.5420477, Longitude: 126.9443481
#
# Address: 서울특별시 동작구 흑석동 143-23
# Latitude: 37.5112743, Longitude: 126.961082
#
# Address: 서울특별시 동작구 사당동 197
# Latitude: 37.489297, Longitude: 126.9656415
#
# Address: 서울특별시 서대문구 연희동 711-32
# Latitude: 37.5585871, Longitude: 126.9349171
#
# Address: 서울특별시 서대문구 홍은동 48-84
# Latitude: 37.5925972, Longitude: 126.9439061
#
# Address: 서울특별시 서대문구 북아현동 153-25
# Latitude: 37.56241680000001, Longitude: 126.9543856
#
# Address: 서울특별시 서초구 반포동 2-1
# Latitude: 37.5077377, Longitude: 126.9967606
#
# Address: 서울특별시 마포구 현석동 128-4
# Latitude: 37.5423181, Longitude: 126.9350313
#
# Address: 서울특별시 서초구 반포동 32-5
# Latitude: 37.5022658, Longitude: 127.0117911
#
# Address: 서울특별시 서초구 반포동 30-15
# Latitude: 37.5030927, Longitude: 127.0162627
#
# Address: 서울특별시 서초구 반포동 30-18
# Latitude: 37.5045432, Longitude: 127.0107723
#
# Address: 서울특별시 서초구 잠원동 66
# Latitude: 37.5088569, Longitude: 127.0084356
#
# Address: 서울특별시 서초구 서초동 1331
# Latitude: 37.4924162, Longitude: 127.0268355
#
# Address: 서울특별시 서초구 잠원동 64-8
# Latitude: 37.5161706, Longitude: 127.0088499
#
# Address: 서울특별시 서초구 잠원동 57
# Latitude: 37.5143551, Longitude: 127.0116337
#
# Address: 서울특별시 서초구 서초동 1310
# Latitude: 37.5007956, Longitude: 127.0238992
#
# Address: 서울특별시 서초구 잠원동 52-1
# Latitude: 37.516786, Longitude: 127.0132266
#
# Address: 서울특별시 송파구 풍납동 388-7
# Latitude: 37.5290622, Longitude: 127.1103949
#
# Address: 서울특별시 송파구 거여동 216-2
# Latitude: 37.494639, Longitude: 127.1508643
#
# Address: 서울특별시 성북구 길음동 1054
# Latitude: 37.6075399, Longitude: 127.0263652
#
# Address: 서울특별시 서초구 잠원동 74-2
# Latitude: 37.5087872, Longitude: 127.0022868
#
# Address: 서울특별시 송파구 가락동 479
# Latitude: 37.4956865, Longitude: 127.1184047
#
# Address: 서울특별시 송파구 거여동 34-2
# Latitude: 37.4929748, Longitude: 127.1504242
#
# Address: 서울특별시 서초구 방배동 1028-1
# Latitude: 37.476554, Longitude: 126.9997209
#
# Address: 서울특별시 양천구 신월동 562-4
# Latitude: 37.5264285, Longitude: 126.8342266
#
# Address: 서울특별시 용산구 이촌동 300-3
# Latitude: 37.5190638, Longitude: 126.9733261
#
# Address: 서울특별시 영등포구 당산동5가 4-2
# Latitude: 37.5312144, Longitude: 126.9001679
#
# Address: 서울특별시 서초구 서초동 1332
# Latitude: 37.4918245, Longitude: 127.0247203
#
# Address: 서울특별시 은평구 응암동 758
# Latitude: 37.5938352, Longitude: 126.9231281
#
# Address: 서울특별시 강남구 역삼동 716-1
# Latitude: 37.50243750000001, Longitude: 127.0493601
#
# Address: 서울특별시 강남구 도곡동 538
# Latitude: 37.4944547, Longitude: 127.0487076
#
# Address: 서울특별시 강남구 청담동 106-21
# Latitude: 37.5277566, Longitude: 127.0514189
#
# Address: 서울특별시 마포구 망원동 239
# Latitude: 37.5554884, Longitude: 126.8998606
#
# Address: 서울특별시 서대문구 홍제동 92-1
# Latitude: 37.5840621, Longitude: 126.9487016
#
# Address: 서울특별시 마포구 합정동 437-18
# Latitude: 37.550959, Longitude: 126.9080726
#
# Address: 서울특별시 서초구 서초동 1681
# Latitude: 37.4970036, Longitude: 127.0204435
#
# Address: 서울특별시 성동구 하왕십리동 845
# Latitude: 37.56398739999999, Longitude: 127.0280247
#
# Address: 서울특별시 성북구 길음동 998
# Latitude: 37.6073524, Longitude: 127.0255114
#
# Address: 서울특별시 성북구 돈암동 13-85
# Latitude: 37.5998253, Longitude: 127.0228224
#
# Address: 서울특별시 송파구 거여동 34
# Latitude: 37.49296940000001, Longitude: 127.1506915
#
# Address: 서울특별시 성동구 금호동1가 598-12
# Latitude: 37.5530784, Longitude: 127.0248311
#
# Address: 서울특별시 송파구 거여동 34-10
# Latitude: 37.4929306, Longitude: 127.1508959
#
# Address: 서울특별시 송파구 송파동 167
# Latitude: 37.5029698, Longitude: 127.1188259
#
# Address: 서울특별시 양천구 신월동 562-3
# Latitude: 37.5264285, Longitude: 126.8342266
#
# Address: 서울특별시 송파구 풍납동 389
# Latitude: 37.5250614, Longitude: 127.1149692
#
# Address: 서울특별시 양천구 신월동 594-13
# Latitude: 37.5264285, Longitude: 126.8342266
#
# Address: 서울특별시 은평구 수색동 326-12
# Latitude: 37.58522019999999, Longitude: 126.8904267
#
# Address: 서울특별시 은평구 수색동 325-17
# Latitude: 37.585477, Longitude: 126.8898433
#
# Address: 서울특별시 강남구 대치동 977
# Latitude: 37.5019346, Longitude: 127.0648263
#
# Address: 서울특별시 강서구 마곡동 744
# Latitude: 37.5706297, Longitude: 126.8298909
#
# Address: 서울특별시 중구 만리동2가 116-4
# Latitude: 37.5542362, Longitude: 126.9647297
#
# Address: 서울특별시 강서구 화곡동 1027-50
# Latitude: 37.5451065, Longitude: 126.8389602
#
# Address: 서울특별시 구로구 항동 가-238
# Latitude: 37.4810318, Longitude: 126.8246024
#
# Address: 서울특별시 동작구 상도동 1000
# Latitude: 37.4987343, Longitude: 126.9440592
#
# Address: 서울특별시 마포구 노고산동 807
# Latitude: 37.5543865, Longitude: 126.9377806
#
# Address: 서울특별시 성북구 장위동 173-114
# Latitude: 37.6190851, Longitude: 127.0506754
#
# Address: 서울특별시 성북구 길음동 498
# Latitude: 37.6085948, Longitude: 127.0220461
#
# Address: 서울특별시 중랑구 면목동 55-14
# Latitude: 37.5860308, Longitude: 127.0960428
#
# Address: 서울특별시 종로구 필운동 1-8
# Latitude: 37.5780745, Longitude: 126.9665414
#
# Address: 서울특별시 용산구 신계동 16-20
# Latitude: 37.534962, Longitude: 126.9650455
#
# Address: 서울특별시 관악구 봉천동 1152
# Latitude: 37.4909713, Longitude: 126.936179
#
# Address: 서울특별시 종로구 원남동 36-1
# Latitude: 37.5756252, Longitude: 126.9982511
#
# Address: 서울특별시 구로구 오류동 279-2
# Latitude: 37.4871557, Longitude: 126.8335908
#
# Address: 서울특별시 구로구 오류동 280
# Latitude: 37.4872327, Longitude: 126.833474
#
# Address: 서울특별시 성북구 정릉동 1287-1
# Latitude: 37.615604, Longitude: 126.9976191
#
# Address: 서울특별시 서초구 내곡동 568
# Latitude: 37.4550628, Longitude: 127.0695079
#
# Address: 서울특별시 용산구 문배동 133-3
# Latitude: 37.5371083, Longitude: 126.96942
#
# Address: 서울특별시 서초구 내곡동 619
# Latitude: 37.4550628, Longitude: 127.0695079
#
# Address: 서울특별시 용산구 효창동 11-168
# Latitude: 37.5392546, Longitude: 126.9623689
#
# Address: 서울특별시 양천구 목동 1078
# Latitude: 37.5360367, Longitude: 126.8745334
#
# Address: 서울특별시 마포구 창전동 27-19
# Latitude: 37.5506586, Longitude: 126.9310253
#
# Address: 서울특별시 양천구 신월동 562-5
# Latitude: 37.5264285, Longitude: 126.8342266
#
# Address: 서울특별시 영등포구 신길동 2039
# Latitude: 37.5060633, Longitude: 126.9136167
#
# Address: 서울특별시 은평구 응암동 626-108
# Latitude: 37.5938352, Longitude: 126.9231281
#
# Address: 서울특별시 성동구 하왕십리동 811
# Latitude: 37.56398739999999, Longitude: 127.0280247
#
# Address: 서울특별시 양천구 신월동 561-2
# Latitude: 37.5264285, Longitude: 126.8342266
#
# Address: 서울특별시 양천구 신월동 593-14
# Latitude: 37.5264285, Longitude: 126.8342266
#
# Address: 서울특별시 중랑구 신내동 1
# Latitude: 37.6123066, Longitude: 127.1138585
#
# Address: 서울특별시 서대문구 남가좌동 458
# Latitude: 37.5756218, Longitude: 126.9194417
#
# Address: 서울특별시 동대문구 답십리동 178
# Latitude: 37.57101950000001, Longitude: 127.0566992
#
# Address: 서울특별시 은평구 증산동 214-8
# Latitude: 37.5813728, Longitude: 126.9036157
#
# Address: 서울특별시 종로구 교남동 126
# Latitude: 37.5716359, Longitude: 126.9639041
#
# Address: 서울특별시 강남구 율현동 686
# Latitude: 37.4708103, Longitude: 127.1120705
#
# Address: 서울특별시 은평구 증산동 216-10
# Latitude: 37.5803063, Longitude: 126.902484
#
# Address: 서울특별시 송파구 거여동 35-7
# Latitude: 37.4930828, Longitude: 127.1477141
#
# Address: 서울특별시 은평구 수색동 328-3
# Latitude: 37.5846889, Longitude: 126.891372
#
# Address: 서울특별시 은평구 응암동 39-23
# Latitude: 37.5970139, Longitude: 126.9306713
#
# Address: 서울특별시 강동구 성내동 547-1
# Latitude: 37.5274774, Longitude: 127.1274385
#
# Address: 서울특별시 은평구 증산동 214-13
# Latitude: 37.5815232, Longitude: 126.9037949
#
# Address: 서울특별시 금천구 시흥동 789
# Latitude: 37.4618465, Longitude: 126.9049612
#
# Address: 서울특별시 서초구 반포동 16-1
# Latitude: 37.5044636, Longitude: 126.997752
#
# Address: 서울특별시 마포구 현석동 128-11
# Latitude: 37.5423181, Longitude: 126.9350313
#
# Address: 서울특별시 동대문구 답십리동 465-2
# Latitude: 37.5704092, Longitude: 127.0484415
#
# Address: 서울특별시 용산구 한강로2가 196
# Latitude: 37.5271432, Longitude: 126.9669048
#
# Address: 서울특별시 강남구 역삼동 762
# Latitude: 37.4951647, Longitude: 127.0472447
#
# Address: 서울특별시 강남구 역삼동 763
# Latitude: 37.4957733, Longitude: 127.0479055
#
# Address: 서울특별시 서초구 서초동 1686-4
# Latitude: 37.4975124, Longitude: 127.0182678
#
# Address: 서울특별시 마포구 토정동 2-4
# Latitude: 37.5406536, Longitude: 126.9398493
#
# Address: 서울특별시 은평구 응암동 757
# Latitude: 37.5938352, Longitude: 126.9231281
#
# Address: 서울특별시 서초구 반포동 30-2
# Latitude: 37.5045432, Longitude: 127.0107723
#
#                    address   Latitude   Longitude
# 28       서울특별시 강남구 개포동 656  37.478567  127.055586
# 229     서울특별시 강남구 삼성동 19-4  37.517525  127.049979
# 311      서울특별시 강남구 역삼동 712  37.501634  127.045528
# 414    서울특별시 강남구 일원동 690-1  37.489970  127.077456
# 647      서울특별시 강동구 상일동 124  37.551235  127.172154
# ...                    ...        ...         ...
# 8934     서울특별시 강남구 역삼동 763  37.495773  127.047905
# 8941  서울특별시 서초구 서초동 1686-4  37.497512  127.018268
# 8930     서울특별시 마포구 토정동 2-4  37.540654  126.939849
# 8901     서울특별시 은평구 응암동 757  37.593835  126.923128
# 8931    서울특별시 서초구 반포동 30-2  37.504543  127.010772
#
# [168 rows x 3 columns]

# %%
valid_addresses_df.to_csv('/content/drive/MyDrive/ML4_adv/last.csv', index=False)

# %%
print(addresses_df)
# Out:
#                    address
# 0      서울특별시 강남구 개포동 658-1
# 1        서울특별시 강남구 개포동 652
# 2       서울특별시 강남구 개포동 12-2
# 3        서울특별시 강남구 개포동 141
# 4        서울특별시 강남구 개포동 187
# ...                    ...
# 8938  서울특별시 구로구 구로동 794-32
# 8939  서울특별시 구로구 구로동 807-39
# 8940    서울특별시 서초구 반포동 16-1
# 8941  서울특별시 서초구 서초동 1686-4
# 8942   서울특별시 용산구 한강로2가 196
#
# [8943 rows x 1 columns]

# %%
# '시군구'와 '지번' 컬럼을 결합하여 'address' 컬럼 생성
train_df['address'] = train_df['시군구'].astype(str) + ' ' + train_df['번지'].astype(str)

# 상위 5개의 데이터만 선택
test_df = train_df.head(5)

# Nominatim 지오코더 객체 생성
geolocator = Nominatim(user_agent="geoapiExercises", timeout=10)

# API 호출을 위한 RateLimiter 설정 (1초에 한 번씩 호출)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# 함수 정의: 주소를 위도와 경도로 변환
def geocode_address(address):
    retries = 3
    for i in range(retries):
        try:
            location = geolocator.geocode(address)
            if location:
                return location.latitude, location.longitude
            else:
                print(f"주소를 찾을 수 없습니다: {address}")
                return None, None
        except Exception as e:
            print(f"예외 발생: {address}, 에러 메시지: {e}, 재시도: {i+1}")
            time.sleep(1)  # 재시도 전 대기 시간
    return None, None

# 위도, 경도 컬럼 추가
test_df['Latitude'], test_df['Longitude'] = zip(*test_df['address'].apply(geocode_address))

# 결과 출력
print(test_df)
# Out:
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 1
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 2
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 3
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 1
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 2
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 3
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 1
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 2
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 3
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 1
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 2
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 3
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 1
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 2
# 예외 발생: 서울특별시 강남구 개포동 658-1, 에러 메시지: Non-successful status code 403, 재시도: 3
#              시군구     번지     본번   부번    아파트명  전용면적(㎡)    계약년월  계약일  층  건축년도  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성    79.97  201712    8  3  1987
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성    79.97  201712   22  4  1987
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성    54.98  201712   28  5  1987
# 3  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성    79.97  201801    3  4  1987
# 4  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성    79.97  201801    8  2  1987
#
#    ...                  단지승인일  사용허가여부 관리비 업로드        좌표X        좌표Y  \
# 0  ...  2022-11-17 13:00:29.0       Y       N  127.05721  37.476763
# 1  ...  2022-11-17 13:00:29.0       Y       N  127.05721  37.476763
# 2  ...  2022-11-17 13:00:29.0       Y       N  127.05721  37.476763
# 3  ...  2022-11-17 13:00:29.0       Y       N  127.05721  37.476763
# 4  ...  2022-11-17 13:00:29.0       Y       N  127.05721  37.476763
#
#                    단지신청일  target              address  Latitude Longitude
# 0  2022-11-17 10:19:06.0  124000  서울특별시 강남구 개포동 658-1      None      None
# 1  2022-11-17 10:19:06.0  123500  서울특별시 강남구 개포동 658-1      None      None
# 2  2022-11-17 10:19:06.0   91500  서울특별시 강남구 개포동 658-1      None      None
# 3  2022-11-17 10:19:06.0  130000  서울특별시 강남구 개포동 658-1      None      None
# 4  2022-11-17 10:19:06.0  117000  서울특별시 강남구 개포동 658-1      None      None
#
# [5 rows x 55 columns]
# <ipython-input-17-53db2de712ca>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Latitude'], test_df['Longitude'] = zip(*test_df['address'].apply(geocode_address))
# <ipython-input-17-53db2de712ca>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df['Latitude'], test_df['Longitude'] = zip(*test_df['address'].apply(geocode_address))

# %%
# Google Maps API 키를 설정합니다
google_api_key = 'AIzaSyAjpnK396O_8o7WEVOzG6b9xUEr4CNmMl8'

# 지오코딩 설정
geolocator = GoogleV3(api_key=google_api_key)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# 단일 주소 테스트
test_address = '서울특별시 강남구 개포동 658-1'  # 실제 주소로 대체하세요
print(f"Testing geocode with address: {test_address}")

def geocode_address(address):
    try:
        location = geocode(address)
        if location:
            return location.latitude, location.longitude
        else:
            print(f"No location found for address: {address}")
            return None, None
    except Exception as e:
        print(f"Error geocoding {address}: {e}")
        return None, None

latitude, longitude = geocode_address(test_address)
print(f"Latitude: {latitude}, Longitude: {longitude}")
# Out:
# Testing geocode with address: 서울특별시 강남구 개포동 658-1
# Latitude: 37.4762828, Longitude: 127.0568408

# %%
google_api_key = 'AIzaSyAjpnK396O_8o7WEVOzG6b9xUEr4CNmMl8'
# '시군구'와 '번지'를 결합하여 전체 주소를 만듭니다
train_df['address'] = train_df['시군구'] + ' ' + train_df['번지']  # 실제 열 이름으로 대체하세요

# 상위 10개 행을 선택합니다
train_df_top10 = train_df.sample(10)

# 지오코딩 설정
geolocator = GoogleV3(api_key=google_api_key)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# 주소를 위도와 경도로 변환하는 함수
def geocode_address(address):
    try:
        location = geocode(address)
        if location:
            return location.latitude, location.longitude
        else:
            print(f"No location found for address: {address}")
            return None, None
    except Exception as e:
        print(f"Error geocoding {address}: {e}")
        return None, None

# 상위 10개 주소에 대해 지오코딩 수행
for index, row in train_df_top10.iterrows():
    address = row['address']
    latitude, longitude = geocode_address(address)
    print(f"Address: {address}")
    print(f"Latitude: {latitude}, Longitude: {longitude}\n")
# Out:
# Address: 서울특별시 양천구 신정동 1293
# Latitude: 37.5080522, Longitude: 126.8443193
#
# Address: 서울특별시 성북구 하월곡동 222
# Latitude: 37.6070327, Longitude: 127.0383656
#
# Address: 서울특별시 서초구 방배동 881-26
# Latitude: 37.4898489, Longitude: 126.9966894
#
# Address: 서울특별시 서초구 반포동 70-1
# Latitude: 37.4991032, Longitude: 127.0008842
#
# Address: 서울특별시 마포구 중동 391
# Latitude: 37.5704843, Longitude: 126.9059376
#
# Address: 서울특별시 서초구 방배동 593-51
# Latitude: 37.4754374, Longitude: 126.994208
#
# Address: 서울특별시 강남구 압구정동 447
# Latitude: 37.5306247, Longitude: 127.0261369
#
# Address: 서울특별시 송파구 석촌동 24-3
# Latitude: 37.5065624, Longitude: 127.1003724
#
# Address: 서울특별시 도봉구 창동 30
# Latitude: 37.6467707, Longitude: 127.0519007
#
# Address: 서울특별시 동대문구 장안동 329-3
# Latitude: 37.5739639, Longitude: 127.0753876

# %%
google_api_key = 'AIzaSyAjpnK396O_8o7WEVOzG6b9xUEr4CNmMl8'

# '시군구'와 '번지'를 결합하여 전체 주소를 만듭니다
train_df['address'] = train_df['시군구'] + ' ' + train_df['번지']  # 실제 열 이름으로 대체하세요

# 지오코딩 설정
geolocator = GoogleV3(api_key=google_api_key)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# 주소를 위도와 경도로 변환하는 함수
def geocode_address(address):
    try:
        location = geocode(address)
        if location:
            return location.latitude, location.longitude
        else:
            print(f"No location found for address: {address}")
            return None, None
    except Exception as e:
        print(f"Error geocoding {address}: {e}")
        return None, None

# 결측치가 있는 행에 대해 지오코딩 수행
for index, row in train_df.iterrows():
    if pd.isna(row['좌표X']) or pd.isna(row['좌표Y']):
        address = row['address']
        latitude, longitude = geocode_address(address)
        print(f"Address: {address}")
        print(f"Latitude: {latitude}, Longitude: {longitude}\n")
        if latitude is not None and longitude is not None:
            train_df.at[index, '좌표X'] = longitude
            train_df.at[index, '좌표Y'] = latitude

# 결과를 저장합니다
train_df.to_csv('/content/drive/MyDrive/ML4_adv/filled_XY_train.csv', index=False)  # 저장할 파일 경로로 대체하세요

print("Geocoding for rows with missing coordinates completed and filled.")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 1164-13
# Latitude: 37.4732828, Longitude: 127.0530959
#
# Address: 서울특별시 강남구 개포동 1164-13
# Latitude: 37.4732828, Longitude: 127.0530959
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 12
# Latitude: 37.4941844, Longitude: 127.0752156
#
# Address: 서울특별시 강남구 개포동 656
# Latitude: 37.4785667, Longitude: 127.0555862
#
# Address: 서울특별시 강남구 개포동 656
# Latitude: 37.4785667, Longitude: 127.0555862
#
# Address: 서울특별시 강남구 개포동 656
# Latitude: 37.4785667, Longitude: 127.0555862
#
# Address: 서울특별시 강남구 개포동 1164-7
# Latitude: 37.4727143, Longitude: 127.0522325
#
# Address: 서울특별시 강남구 개포동 166-4
# Latitude: 37.4829138, Longitude: 127.0612903
#
# Address: 서울특별시 강남구 개포동 179
# Latitude: 37.48818410000001, Longitude: 127.0623884
#
# Address: 서울특별시 강남구 개포동 179
# Latitude: 37.48818410000001, Longitude: 127.0623884
#
# Address: 서울특별시 강남구 개포동 179
# Latitude: 37.48818410000001, Longitude: 127.0623884
#
# Address: 서울특별시 강남구 개포동 179
# Latitude: 37.48818410000001, Longitude: 127.0623884
#
# Address: 서울특별시 강남구 개포동 179
# Latitude: 37.48818410000001, Longitude: 127.0623884
#
# Address: 서울특별시 강남구 개포동 179
# Latitude: 37.48818410000001, Longitude: 127.0623884
#
# Address: 서울특별시 강남구 개포동 179
# Latitude: 37.48818410000001, Longitude: 127.0623884
#
# Address: 서울특별시 강남구 개포동 179
# Latitude: 37.48818410000001, Longitude: 127.0623884
#
# Address: 서울특별시 강남구 개포동 179
# Latitude: 37.48818410000001, Longitude: 127.0623884
#
# Address: 서울특별시 강남구 개포동 651-1
# Latitude: 37.4848284, Longitude: 127.0572512
#
# Address: 서울특별시 강남구 개포동 651-1
# Latitude: 37.4848284, Longitude: 127.0572512
#
# Address: 서울특별시 강남구 개포동 651-1
# Latitude: 37.4848284, Longitude: 127.0572512
#
# Address: 서울특별시 강남구 개포동 651-1
# Latitude: 37.4848284, Longitude: 127.0572512
#
# Address: 서울특별시 강남구 개포동 651-1
# Latitude: 37.4848284, Longitude: 127.0572512
#
# Address: 서울특별시 강남구 개포동 651-1
# Latitude: 37.4848284, Longitude: 127.0572512
#
# Address: 서울특별시 강남구 개포동 1260-2
# Latitude: 37.4795087, Longitude: 127.0487812
#
# Address: 서울특별시 강남구 개포동 1260-2
# Latitude: 37.4795087, Longitude: 127.0487812
#
# Address: 서울특별시 강남구 개포동 1260-4
# Latitude: 37.4795455, Longitude: 127.0491299
#
# Address: 서울특별시 강남구 개포동 172-3
# Latitude: 37.4843078, Longitude: 127.0599654
#
# Address: 서울특별시 강남구 개포동 172-3
# Latitude: 37.4843078, Longitude: 127.0599654
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 653
# Latitude: 37.4826691, Longitude: 127.0544261
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 654
# Latitude: 37.4824771, Longitude: 127.0512529
#
# Address: 서울특별시 강남구 개포동 177
# Latitude: 37.4878919, Longitude: 127.0609561
#
# Address: 서울특별시 강남구 개포동 177
# Latitude: 37.4878919, Longitude: 127.0609561
#
# Address: 서울특별시 강남구 개포동 177
# Latitude: 37.4878919, Longitude: 127.0609561
#
# Address: 서울특별시 강남구 개포동 177
# Latitude: 37.4878919, Longitude: 127.0609561
#
# Address: 서울특별시 강남구 논현동 195-1
# Latitude: 37.5068611, Longitude: 127.02875
#
# Address: 서울특별시 강남구 논현동 195-1
# Latitude: 37.5068611, Longitude: 127.02875
#
# Address: 서울특별시 강남구 논현동 195-1
# Latitude: 37.5068611, Longitude: 127.02875
#
# Address: 서울특별시 강남구 논현동 195-1
# Latitude: 37.5068611, Longitude: 127.02875
#
# Address: 서울특별시 강남구 논현동 196
# Latitude: 37.5063694, Longitude: 127.0276374
#
# Address: 서울특별시 강남구 논현동 196
# Latitude: 37.5063694, Longitude: 127.0276374
#
# Address: 서울특별시 강남구 논현동 196
# Latitude: 37.5063694, Longitude: 127.0276374
#
# Address: 서울특별시 강남구 논현동 196
# Latitude: 37.5063694, Longitude: 127.0276374
#
# Address: 서울특별시 강남구 논현동 196
# Latitude: 37.5063694, Longitude: 127.0276374
#
# Address: 서울특별시 강남구 논현동 196
# Latitude: 37.5063694, Longitude: 127.0276374
#
# Address: 서울특별시 강남구 논현동 196
# Latitude: 37.5063694, Longitude: 127.0276374
#
# Address: 서울특별시 강남구 논현동 274
# Latitude: 37.5106814, Longitude: 127.0381991
#
# Address: 서울특별시 강남구 논현동 103-11
# Latitude: 37.5196765, Longitude: 127.038856
#
# Address: 서울특별시 강남구 논현동 103-11
# Latitude: 37.5196765, Longitude: 127.038856
#
# Address: 서울특별시 강남구 논현동 212-13
# Latitude: 37.5135183, Longitude: 127.0341414
#
# Address: 서울특별시 강남구 논현동 192-3
# Latitude: 37.5081759, Longitude: 127.0328325
#
# Address: 서울특별시 강남구 논현동 192-3
# Latitude: 37.5081759, Longitude: 127.0328325
#
# Address: 서울특별시 강남구 논현동 205-2
# Latitude: 37.5068229, Longitude: 127.0303956
#
# Address: 서울특별시 강남구 논현동 205-2
# Latitude: 37.5068229, Longitude: 127.0303956
#
# Address: 서울특별시 강남구 논현동 205-2
# Latitude: 37.5068229, Longitude: 127.0303956
#
# Address: 서울특별시 강남구 논현동 205-2
# Latitude: 37.5068229, Longitude: 127.0303956
#
# Address: 서울특별시 강남구 논현동 252
# Latitude: 37.5140421, Longitude: 127.0387733
#
# Address: 서울특별시 강남구 논현동 252
# Latitude: 37.5140421, Longitude: 127.0387733
#
# Address: 서울특별시 강남구 논현동 252
# Latitude: 37.5140421, Longitude: 127.0387733
#
# Address: 서울특별시 강남구 논현동 214-2
# Latitude: 37.5127468, Longitude: 127.0327228
#
# Address: 서울특별시 강남구 논현동 214-2
# Latitude: 37.5127468, Longitude: 127.0327228
#
# Address: 서울특별시 강남구 논현동 214-2
# Latitude: 37.5127468, Longitude: 127.0327228
#
# Address: 서울특별시 강남구 논현동 214-2
# Latitude: 37.5127468, Longitude: 127.0327228
#
# Address: 서울특별시 강남구 논현동 214-2
# Latitude: 37.5127468, Longitude: 127.0327228
#
# Address: 서울특별시 강남구 논현동 214-2
# Latitude: 37.5127468, Longitude: 127.0327228
#
# Address: 서울특별시 강남구 논현동 102-9
# Latitude: 37.5192639, Longitude: 127.0399268
#
# Address: 서울특별시 강남구 논현동 215-14
# Latitude: 37.5124715, Longitude: 127.0322748
#
# Address: 서울특별시 강남구 논현동 215-14
# Latitude: 37.5124715, Longitude: 127.0322748
#
# Address: 서울특별시 강남구 논현동 108
# Latitude: 37.5184523, Longitude: 127.03803
#
# Address: 서울특별시 강남구 논현동 108
# Latitude: 37.5184523, Longitude: 127.03803
#
# Address: 서울특별시 강남구 논현동 108
# Latitude: 37.5184523, Longitude: 127.03803
#
# Address: 서울특별시 강남구 논현동 241-1
# Latitude: 37.5165513, Longitude: 127.0401391
#
# Address: 서울특별시 강남구 논현동 241-1
# Latitude: 37.5165513, Longitude: 127.0401391
#
# Address: 서울특별시 강남구 논현동 241-1
# Latitude: 37.5165513, Longitude: 127.0401391
#
# Address: 서울특별시 강남구 논현동 241-1
# Latitude: 37.5165513, Longitude: 127.0401391
#
# Address: 서울특별시 강남구 논현동 241-1
# Latitude: 37.5165513, Longitude: 127.0401391
#
# Address: 서울특별시 강남구 논현동 241-1
# Latitude: 37.5165513, Longitude: 127.0401391
#
# Address: 서울특별시 강남구 논현동 241-1
# Latitude: 37.5165513, Longitude: 127.0401391
#
# Address: 서울특별시 강남구 논현동 196-4
# Latitude: 37.5067119, Longitude: 127.0283183
#
# Address: 서울특별시 강남구 논현동 196-4
# Latitude: 37.5067119, Longitude: 127.0283183
#
# Address: 서울특별시 강남구 논현동 105-3
# Latitude: 37.5187801, Longitude: 127.0375072
#
# Address: 서울특별시 강남구 논현동 105-3
# Latitude: 37.5187801, Longitude: 127.0375072
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 275
# Latitude: 37.5103561, Longitude: 127.0376521
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 105
# Latitude: 37.5193536, Longitude: 127.0365755
#
# Address: 서울특별시 강남구 논현동 252-1
# Latitude: 37.5135469, Longitude: 127.0387754
#
# Address: 서울특별시 강남구 논현동 252-1
# Latitude: 37.5135469, Longitude: 127.0387754
#
# Address: 서울특별시 강남구 논현동 252-1
# Latitude: 37.5135469, Longitude: 127.0387754
#
# Address: 서울특별시 강남구 논현동 252-1
# Latitude: 37.5135469, Longitude: 127.0387754
#
# Address: 서울특별시 강남구 논현동 258
# Latitude: 37.5125346, Longitude: 127.0383696
#
# Address: 서울특별시 강남구 논현동 258
# Latitude: 37.5125346, Longitude: 127.0383696
#
# Address: 서울특별시 강남구 논현동 258
# Latitude: 37.5125346, Longitude: 127.0383696
#
# Address: 서울특별시 강남구 논현동 258
# Latitude: 37.5125346, Longitude: 127.0383696
#
# Address: 서울특별시 강남구 논현동 258
# Latitude: 37.5125346, Longitude: 127.0383696
#
# Address: 서울특별시 강남구 논현동 258
# Latitude: 37.5125346, Longitude: 127.0383696
#
# Address: 서울특별시 강남구 논현동 258
# Latitude: 37.5125346, Longitude: 127.0383696
#
# Address: 서울특별시 강남구 논현동 216-1
# Latitude: 37.5121764, Longitude: 127.0323823
#
# Address: 서울특별시 강남구 논현동 216-1
# Latitude: 37.5121764, Longitude: 127.0323823
#
# Address: 서울특별시 강남구 논현동 47-11
# Latitude: 37.5129102, Longitude: 127.0226388
#
# Address: 서울특별시 강남구 논현동 43-3
# Latitude: 37.5132993, Longitude: 127.024198
#
# Address: 서울특별시 강남구 논현동 55
# Latitude: 37.512603, Longitude: 127.0238874
#
# Address: 서울특별시 강남구 논현동 55
# Latitude: 37.512603, Longitude: 127.0238874
#
# Address: 서울특별시 강남구 논현동 55
# Latitude: 37.512603, Longitude: 127.0238874
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 22
# Latitude: 37.5147153, Longitude: 127.0226688
#
# Address: 서울특별시 강남구 논현동 103
# Latitude: 37.5196301, Longitude: 127.0381309
#
# Address: 서울특별시 강남구 논현동 103
# Latitude: 37.5196301, Longitude: 127.0381309
#
# Address: 서울특별시 강남구 논현동 103
# Latitude: 37.5196301, Longitude: 127.0381309
#
# Address: 서울특별시 강남구 논현동 103
# Latitude: 37.5196301, Longitude: 127.0381309
#
# Address: 서울특별시 강남구 논현동 103
# Latitude: 37.5196301, Longitude: 127.0381309
#
# Address: 서울특별시 강남구 논현동 103
# Latitude: 37.5196301, Longitude: 127.0381309
#
# Address: 서울특별시 강남구 논현동 103
# Latitude: 37.5196301, Longitude: 127.0381309
#
# Address: 서울특별시 강남구 논현동 103
# Latitude: 37.5196301, Longitude: 127.0381309
#
# Address: 서울특별시 강남구 논현동 103
# Latitude: 37.5196301, Longitude: 127.0381309
#
# Address: 서울특별시 강남구 논현동 103
# Latitude: 37.5196301, Longitude: 127.0381309
#
# Address: 서울특별시 강남구 논현동 107-44
# Latitude: 37.5178339, Longitude: 127.037354
#
# Address: 서울특별시 강남구 논현동 107-44
# Latitude: 37.5178339, Longitude: 127.037354
#
# Address: 서울특별시 강남구 논현동 180-6
# Latitude: 37.5075667, Longitude: 127.0279892
#
# Address: 서울특별시 강남구 논현동 138-9
# Latitude: 37.510238, Longitude: 127.0261074
#
# Address: 서울특별시 강남구 논현동 194-22
# Latitude: 37.507207, Longitude: 127.030696
#
# Address: 서울특별시 강남구 논현동 194-22
# Latitude: 37.507207, Longitude: 127.030696
#
# Address: 서울특별시 강남구 논현동 229-13
# Latitude: 37.5092521, Longitude: 127.0341167
#
# Address: 서울특별시 강남구 논현동 229-13
# Latitude: 37.5092521, Longitude: 127.0341167
#
# Address: 서울특별시 강남구 논현동 44-9
# Latitude: 37.5137281, Longitude: 127.0236446
#
# Address: 서울특별시 강남구 논현동 62-3
# Latitude: 37.5202882, Longitude: 127.0322154
#
# Address: 서울특별시 강남구 논현동 62-3
# Latitude: 37.5202882, Longitude: 127.0322154
#
# Address: 서울특별시 강남구 논현동 62-3
# Latitude: 37.5202882, Longitude: 127.0322154
#
# Address: 서울특별시 강남구 논현동 267-18
# Latitude: 37.5126506, Longitude: 127.0422516
#
# Address: 서울특별시 강남구 논현동 267-18
# Latitude: 37.5126506, Longitude: 127.0422516
#
# Address: 서울특별시 강남구 논현동 104-23
# Latitude: 37.5190516, Longitude: 127.0387295
#
# Address: 서울특별시 강남구 논현동 228-9
# Latitude: 37.5089626, Longitude: 127.0338244
#
# Address: 서울특별시 강남구 논현동 80-13
# Latitude: 37.5162255, Longitude: 127.0305873
#
# Address: 서울특별시 강남구 논현동 217-34
# Latitude: 37.5126054, Longitude: 127.0338086
#
# Address: 서울특별시 강남구 논현동 79-7
# Latitude: 37.5170403, Longitude: 127.0313014
#
# Address: 서울특별시 강남구 논현동 79-7
# Latitude: 37.5170403, Longitude: 127.0313014
#
# Address: 서울특별시 강남구 논현동 221-7
# Latitude: 37.5097158, Longitude: 127.0335241
#
# Address: 서울특별시 강남구 논현동 221-7
# Latitude: 37.5097158, Longitude: 127.0335241
#
# Address: 서울특별시 강남구 논현동 221-7
# Latitude: 37.5097158, Longitude: 127.0335241
#
# Address: 서울특별시 강남구 논현동 105-4
# Latitude: 37.520717, Longitude: 127.0371476
#
# Address: 서울특별시 강남구 논현동 105-4
# Latitude: 37.520717, Longitude: 127.0371476
#
# Address: 서울특별시 강남구 논현동 105-4
# Latitude: 37.520717, Longitude: 127.0371476
#
# Address: 서울특별시 강남구 논현동 105-4
# Latitude: 37.520717, Longitude: 127.0371476
#
# Address: 서울특별시 강남구 논현동 194-23
# Latitude: 37.5076849, Longitude: 127.0307289
#
# Address: 서울특별시 강남구 논현동 194-23
# Latitude: 37.5076849, Longitude: 127.0307289
#
# Address: 서울특별시 강남구 논현동 194-23
# Latitude: 37.5076849, Longitude: 127.0307289
#
# Address: 서울특별시 강남구 논현동 194-23
# Latitude: 37.5076849, Longitude: 127.0307289
#
# Address: 서울특별시 강남구 논현동 194-23
# Latitude: 37.5076849, Longitude: 127.0307289
#
# Address: 서울특별시 강남구 논현동 194-23
# Latitude: 37.5076849, Longitude: 127.0307289
#
# Address: 서울특별시 강남구 논현동 261-8
# Latitude: 37.5115862, Longitude: 127.0367687
#
# Address: 서울특별시 강남구 논현동 261-8
# Latitude: 37.5115862, Longitude: 127.0367687
#
# Address: 서울특별시 강남구 논현동 261-8
# Latitude: 37.5115862, Longitude: 127.0367687
#
# Address: 서울특별시 강남구 논현동 261-8
# Latitude: 37.5115862, Longitude: 127.0367687
#
# Address: 서울특별시 강남구 논현동 261
# Latitude: 37.5116241, Longitude: 127.0363107
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 503
# Latitude: 37.491125, Longitude: 127.059896
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 500
# Latitude: 37.4908388, Longitude: 127.0572409
#
# Address: 서울특별시 강남구 대치동 891-26
# Latitude: 37.5046324, Longitude: 127.053752
#
# Address: 서울특별시 강남구 대치동 891-26
# Latitude: 37.5046324, Longitude: 127.053752
#
# Address: 서울특별시 강남구 대치동 891-23
# Latitude: 37.5050809, Longitude: 127.0535226
#
# Address: 서울특별시 강남구 대치동 891-23
# Latitude: 37.5050809, Longitude: 127.0535226
#
# Address: 서울특별시 강남구 대치동 891-23
# Latitude: 37.5050809, Longitude: 127.0535226
#
# Address: 서울특별시 강남구 대치동 891-23
# Latitude: 37.5050809, Longitude: 127.0535226
#
# Address: 서울특별시 강남구 대치동 891-23
# Latitude: 37.5050809, Longitude: 127.0535226
#
# Address: 서울특별시 강남구 대치동 891-23
# Latitude: 37.5050809, Longitude: 127.0535226
#
# Address: 서울특별시 강남구 대치동 1029
# Latitude: 37.4957694, Longitude: 127.0603513
#
# Address: 서울특별시 강남구 대치동 1029
# Latitude: 37.4957694, Longitude: 127.0603513
#
# Address: 서울특별시 강남구 대치동 1029
# Latitude: 37.4957694, Longitude: 127.0603513
#
# Address: 서울특별시 강남구 대치동 1029
# Latitude: 37.4957694, Longitude: 127.0603513
#
# Address: 서울특별시 강남구 대치동 1029
# Latitude: 37.4957694, Longitude: 127.0603513
#
# Address: 서울특별시 강남구 대치동 1029
# Latitude: 37.4957694, Longitude: 127.0603513
#
# Address: 서울특별시 강남구 대치동 1029
# Latitude: 37.4957694, Longitude: 127.0603513
#
# Address: 서울특별시 강남구 대치동 1029
# Latitude: 37.4957694, Longitude: 127.0603513
#
# Address: 서울특별시 강남구 대치동 1029
# Latitude: 37.4957694, Longitude: 127.0603513
#
# Address: 서울특별시 강남구 대치동 1029
# Latitude: 37.4957694, Longitude: 127.0603513
#
# Address: 서울특별시 강남구 대치동 1029
# Latitude: 37.4957694, Longitude: 127.0603513
#
# Address: 서울특별시 강남구 대치동 891-28
# Latitude: 37.5045439, Longitude: 127.0542093
#
# Address: 서울특별시 강남구 대치동 891-28
# Latitude: 37.5045439, Longitude: 127.0542093
#
# Address: 서울특별시 강남구 대치동 891-28
# Latitude: 37.5045439, Longitude: 127.0542093
#
# Address: 서울특별시 강남구 대치동 891-28
# Latitude: 37.5045439, Longitude: 127.0542093
#
# Address: 서울특별시 강남구 대치동 891-28
# Latitude: 37.5045439, Longitude: 127.0542093
#
# Address: 서울특별시 강남구 대치동 890-42
# Latitude: 37.5043148, Longitude: 127.052556
#
# Address: 서울특별시 강남구 대치동 63
# Latitude: 37.5002334, Longitude: 127.0691394
#
# Address: 서울특별시 강남구 대치동 63
# Latitude: 37.5002334, Longitude: 127.0691394
#
# Address: 서울특별시 강남구 대치동 63
# Latitude: 37.5002334, Longitude: 127.0691394
#
# Address: 서울특별시 강남구 대치동 63
# Latitude: 37.5002334, Longitude: 127.0691394
#
# Address: 서울특별시 강남구 대치동 1015-6
# Latitude: 37.4970495, Longitude: 127.0584933
#
# Address: 서울특별시 강남구 대치동 1015-6
# Latitude: 37.4970495, Longitude: 127.0584933
#
# Address: 서울특별시 강남구 대치동 1015-6
# Latitude: 37.4970495, Longitude: 127.0584933
#
# Address: 서울특별시 강남구 대치동 907-2
# Latitude: 37.5013869, Longitude: 127.0515928
#
# Address: 서울특별시 강남구 대치동 907-2
# Latitude: 37.5013869, Longitude: 127.0515928
#
# Address: 서울특별시 강남구 대치동 907-2
# Latitude: 37.5013869, Longitude: 127.0515928
#
# Address: 서울특별시 강남구 대치동 907-2
# Latitude: 37.5013869, Longitude: 127.0515928
#
# Address: 서울특별시 강남구 대치동 938-11
# Latitude: 37.4977981, Longitude: 127.0554559
#
# Address: 서울특별시 강남구 대치동 938-11
# Latitude: 37.4977981, Longitude: 127.0554559
#
# Address: 서울특별시 강남구 대치동 938-13
# Latitude: 37.4980138, Longitude: 127.055872
#
# Address: 서울특별시 강남구 대치동 938-13
# Latitude: 37.4980138, Longitude: 127.055872
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 670
# Latitude: 37.4927927, Longitude: 127.0557447
#
# Address: 서울특별시 강남구 대치동 920-32
# Latitude: 37.4997269, Longitude: 127.0526025
#
# Address: 서울특별시 강남구 대치동 920-32
# Latitude: 37.4997269, Longitude: 127.0526025
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 1027
# Latitude: 37.4942974, Longitude: 127.0580036
#
# Address: 서울특별시 강남구 대치동 893
# Latitude: 37.5047553, Longitude: 127.0564488
#
# Address: 서울특별시 강남구 대치동 893
# Latitude: 37.5047553, Longitude: 127.0564488
#
# Address: 서울특별시 강남구 대치동 893
# Latitude: 37.5047553, Longitude: 127.0564488
#
# Address: 서울특별시 강남구 대치동 893
# Latitude: 37.5047553, Longitude: 127.0564488
#
# Address: 서울특별시 강남구 대치동 901-51
# Latitude: 37.5029709, Longitude: 127.0554655
#
# Address: 서울특별시 강남구 대치동 1014-1
# Latitude: 37.4970236, Longitude: 127.0575271
#
# Address: 서울특별시 강남구 대치동 1014-1
# Latitude: 37.4970236, Longitude: 127.0575271
#
# Address: 서울특별시 강남구 대치동 1014-1
# Latitude: 37.4970236, Longitude: 127.0575271
#
# Address: 서울특별시 강남구 대치동 1016-2
# Latitude: 37.4975704, Longitude: 127.0601171
#
# Address: 서울특별시 강남구 대치동 1016-2
# Latitude: 37.4975704, Longitude: 127.0601171
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# Latitude: 37.4921261, Longitude: 127.0625653
#
# Address: 서울특별시 강남구 대치동 506
# ...
# Latitude: 37.506168, Longitude: 127.0509289
#
# Address: 서울특별시 강남구 삼성동 99-12
# Latitude: 37.5170635, Longitude: 127.065529
#
# Address: 서울특별시 강남구 삼성동 99-12
# Latitude: 37.5170635, Longitude: 127.065529
#
# Address: 서울특별시 강남구 삼성동 99-12
# Latitude: 37.5170635, Longitude: 127.065529
#
# Address: 서울특별시 강남구 삼성동 99-12
# Latitude: 37.5170635, Longitude: 127.065529
#
# Address: 서울특별시 강남구 삼성동 99-12
# Latitude: 37.5170635, Longitude: 127.065529
#
# Address: 서울특별시 강남구 삼성동 5-3
# Latitude: 37.5169778, Longitude: 127.0464382
#
# Address: 서울특별시 강남구 삼성동 36-12
# Latitude: 37.511855, Longitude: 127.044707
#
# Address: 서울특별시 강남구 삼성동 82-6
# Latitude: 37.5189533, Longitude: 127.0616936
#
# Address: 서울특별시 강남구 삼성동 98-18
# Latitude: 37.5181296, Longitude: 127.0645716
#
# Address: 서울특별시 강남구 삼성동 98-9
# Latitude: 37.5182866, Longitude: 127.0643055
#
# Address: 서울특별시 강남구 삼성동 98-9
# Latitude: 37.5182866, Longitude: 127.0643055
#
# Address: 서울특별시 강남구 삼성동 33-22
# Latitude: 37.512864, Longitude: 127.0440149
#
# Address: 서울특별시 강남구 삼성동 33-22
# Latitude: 37.512864, Longitude: 127.0440149
#
# Address: 서울특별시 강남구 삼성동 108-2
# Latitude: 37.51517, Longitude: 127.062263
#
# Address: 서울특별시 강남구 삼성동 108-2
# Latitude: 37.51517, Longitude: 127.062263
#
# Address: 서울특별시 강남구 삼성동 100-14
# Latitude: 37.5162493, Longitude: 127.0657708
#
# Address: 서울특별시 강남구 삼성동 100-14
# Latitude: 37.5162493, Longitude: 127.0657708
#
# Address: 서울특별시 강남구 삼성동 103-22
# Latitude: 37.5171344, Longitude: 127.063973
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 7-3
# Latitude: 37.5161513, Longitude: 127.0434365
#
# Address: 서울특별시 강남구 삼성동 104-10
# Latitude: 37.5162471, Longitude: 127.0628497
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 11
# Latitude: 37.5152737, Longitude: 127.0447446
#
# Address: 서울특별시 강남구 삼성동 107
# Latitude: 37.5148855, Longitude: 127.0604126
#
# Address: 서울특별시 강남구 삼성동 107
# Latitude: 37.5148855, Longitude: 127.0604126
#
# Address: 서울특별시 강남구 삼성동 107
# Latitude: 37.5148855, Longitude: 127.0604126
#
# Address: 서울특별시 강남구 삼성동 107
# Latitude: 37.5148855, Longitude: 127.0604126
#
# Address: 서울특별시 강남구 삼성동 107
# Latitude: 37.5148855, Longitude: 127.0604126
#
# Address: 서울특별시 강남구 삼성동 147-2
# Latitude: 37.5132359, Longitude: 127.0559719
#
# Address: 서울특별시 강남구 삼성동 147-2
# Latitude: 37.5132359, Longitude: 127.0559719
#
# Address: 서울특별시 강남구 삼성동 147-2
# Latitude: 37.5132359, Longitude: 127.0559719
#
# Address: 서울특별시 강남구 삼성동 147-2
# Latitude: 37.5132359, Longitude: 127.0559719
#
# Address: 서울특별시 강남구 삼성동 147-2
# Latitude: 37.5132359, Longitude: 127.0559719
#
# Address: 서울특별시 강남구 삼성동 98-11
# Latitude: 37.51785599999999, Longitude: 127.0641402
#
# Address: 서울특별시 강남구 삼성동 98-11
# Latitude: 37.51785599999999, Longitude: 127.0641402
#
# Address: 서울특별시 강남구 삼성동 98-11
# Latitude: 37.51785599999999, Longitude: 127.0641402
#
# Address: 서울특별시 강남구 삼성동 99-13
# Latitude: 37.516994, Longitude: 127.0651395
#
# Address: 서울특별시 강남구 삼성동 99-13
# Latitude: 37.516994, Longitude: 127.0651395
#
# Address: 서울특별시 강남구 삼성동 99
# Latitude: 37.5174375, Longitude: 127.0648651
#
# Address: 서울특별시 강남구 삼성동 99
# Latitude: 37.5174375, Longitude: 127.0648651
#
# Address: 서울특별시 강남구 삼성동 99
# Latitude: 37.5174375, Longitude: 127.0648651
#
# Address: 서울특별시 강남구 삼성동 99
# Latitude: 37.5174375, Longitude: 127.0648651
#
# Address: 서울특별시 강남구 삼성동 113-17
# Latitude: 37.5104955, Longitude: 127.0470289
#
# Address: 서울특별시 강남구 삼성동 113-17
# Latitude: 37.5104955, Longitude: 127.0470289
#
# Address: 서울특별시 강남구 삼성동 113-17
# Latitude: 37.5104955, Longitude: 127.0470289
#
# Address: 서울특별시 강남구 삼성동 113-17
# Latitude: 37.5104955, Longitude: 127.0470289
#
# Address: 서울특별시 강남구 삼성동 47-18
# Latitude: 37.5134619, Longitude: 127.0495372
#
# Address: 서울특별시 강남구 삼성동 110-2
# Latitude: 37.5155618, Longitude: 127.0657575
#
# Address: 서울특별시 강남구 삼성동 110-2
# Latitude: 37.5155618, Longitude: 127.0657575
#
# Address: 서울특별시 강남구 삼성동 110-2
# Latitude: 37.5155618, Longitude: 127.0657575
#
# Address: 서울특별시 강남구 삼성동 110-2
# Latitude: 37.5155618, Longitude: 127.0657575
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 17
# Latitude: 37.5177635, Longitude: 127.0486776
#
# Address: 서울특별시 강남구 삼성동 43
# Latitude: 37.5131207, Longitude: 127.0477965
#
# Address: 서울특별시 강남구 삼성동 43
# Latitude: 37.5131207, Longitude: 127.0477965
#
# Address: 서울특별시 강남구 삼성동 43
# Latitude: 37.5131207, Longitude: 127.0477965
#
# Address: 서울특별시 강남구 삼성동 43
# Latitude: 37.5131207, Longitude: 127.0477965
#
# Address: 서울특별시 강남구 삼성동 43
# Latitude: 37.5131207, Longitude: 127.0477965
#
# Address: 서울특별시 강남구 삼성동 43
# Latitude: 37.5131207, Longitude: 127.0477965
#
# Address: 서울특별시 강남구 삼성동 43
# Latitude: 37.5131207, Longitude: 127.0477965
#
# Address: 서울특별시 강남구 삼성동 43
# Latitude: 37.5131207, Longitude: 127.0477965
#
# Address: 서울특별시 강남구 삼성동 43
# Latitude: 37.5131207, Longitude: 127.0477965
#
# Address: 서울특별시 강남구 삼성동 8-2
# Latitude: 37.5155551, Longitude: 127.0423675
#
# Address: 서울특별시 강남구 삼성동 8-2
# Latitude: 37.5155551, Longitude: 127.0423675
#
# Address: 서울특별시 강남구 삼성동 8-2
# Latitude: 37.5155551, Longitude: 127.0423675
#
# Address: 서울특별시 강남구 삼성동 121-38
# Latitude: 37.5103886, Longitude: 127.053406
#
# Address: 서울특별시 강남구 삼성동 114-11
# Latitude: 37.5114528, Longitude: 127.0488389
#
# Address: 서울특별시 강남구 삼성동 3-2
# Latitude: 37.5174837, Longitude: 127.0443789
#
# Address: 서울특별시 강남구 삼성동 101
# Latitude: 37.516372, Longitude: 127.0649994
#
# Address: 서울특별시 강남구 삼성동 4-6
# Latitude: 37.5173885, Longitude: 127.0455038
#
# Address: 서울특별시 강남구 삼성동 4-6
# Latitude: 37.5173885, Longitude: 127.0455038
#
# Address: 서울특별시 강남구 삼성동 4-6
# Latitude: 37.5173885, Longitude: 127.0455038
#
# Address: 서울특별시 강남구 삼성동 4-6
# Latitude: 37.5173885, Longitude: 127.0455038
#
# Address: 서울특별시 강남구 삼성동 4-6
# Latitude: 37.5173885, Longitude: 127.0455038
#
# Address: 서울특별시 강남구 삼성동 4-6
# Latitude: 37.5173885, Longitude: 127.0455038
#
# Address: 서울특별시 강남구 삼성동 4-6
# Latitude: 37.5173885, Longitude: 127.0455038
#
# Address: 서울특별시 강남구 삼성동 4-6
# Latitude: 37.5173885, Longitude: 127.0455038
#
# Address: 서울특별시 강남구 삼성동 4-6
# Latitude: 37.5173885, Longitude: 127.0455038
#
# Address: 서울특별시 강남구 삼성동 82-1
# Latitude: 37.5194438, Longitude: 127.0610352
#
# Address: 서울특별시 강남구 삼성동 82-1
# Latitude: 37.5194438, Longitude: 127.0610352
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 16-2
# Latitude: 37.5163059, Longitude: 127.0484473
#
# Address: 서울특별시 강남구 삼성동 52-9
# Latitude: 37.5185293, Longitude: 127.0511296
#
# Address: 서울특별시 강남구 삼성동 52-9
# Latitude: 37.5185293, Longitude: 127.0511296
#
# Address: 서울특별시 강남구 삼성동 52-9
# Latitude: 37.5185293, Longitude: 127.0511296
#
# Address: 서울특별시 강남구 삼성동 52-9
# Latitude: 37.5185293, Longitude: 127.0511296
#
# Address: 서울특별시 강남구 삼성동 29-19
# Latitude: 37.5143372, Longitude: 127.0458109
#
# Address: 서울특별시 강남구 삼성동 29-19
# Latitude: 37.5143372, Longitude: 127.0458109
#
# Address: 서울특별시 강남구 삼성동 129-5
# Latitude: 37.508806, Longitude: 127.054425
#
# Address: 서울특별시 강남구 삼성동 104
# Latitude: 37.5161478, Longitude: 127.0622076
#
# Address: 서울특별시 강남구 삼성동 104
# Latitude: 37.5161478, Longitude: 127.0622076
#
# Address: 서울특별시 강남구 삼성동 104
# Latitude: 37.5161478, Longitude: 127.0622076
#
# Address: 서울특별시 강남구 삼성동 104
# Latitude: 37.5161478, Longitude: 127.0622076
#
# Address: 서울특별시 강남구 삼성동 19-4
# Latitude: 37.5175246, Longitude: 127.0499786
#
# Address: 서울특별시 강남구 삼성동 19-4
# Latitude: 37.5175246, Longitude: 127.0499786
#
# Address: 서울특별시 강남구 삼성동 19-4
# Latitude: 37.5175246, Longitude: 127.0499786
#
# Address: 서울특별시 강남구 삼성동 19-4
# Latitude: 37.5175246, Longitude: 127.0499786
#
# Address: 서울특별시 강남구 삼성동 19-4
# Latitude: 37.5175246, Longitude: 127.0499786
#
# Address: 서울특별시 강남구 삼성동 19-4
# Latitude: 37.5175246, Longitude: 127.0499786
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 2
# Latitude: 37.5170294, Longitude: 127.0427453
#
# Address: 서울특별시 강남구 삼성동 3-3
# Latitude: 37.51744780000001, Longitude: 127.0448485
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-12af23e3825c> in <cell line: 24>()
#      25     if pd.isna(row['좌표X']) or pd.isna(row['좌표Y']):
#      26         address = row['address']
# ---> 27         latitude, longitude = geocode_address(address)
#      28         print(f"Address: {address}")
#      29         print(f"Latitude: {latitude}, Longitude: {longitude}\n")
#
# <ipython-input-12-12af23e3825c> in geocode_address(address)
#      11 def geocode_address(address):
#      12     try:
# ---> 13         location = geocode(address)
#      14         if location:
#      15             return location.latitude, location.longitude
#
# /usr/local/lib/python3.10/dist-packages/geopy/extra/rate_limiter.py in __call__(self, *args, **kwargs)
#     270         gen = self._retries_gen(args, kwargs)
#     271         for _ in gen:
# --> 272             self._acquire_request_slot()
#     273             try:
#     274                 res = self.func(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/geopy/extra/rate_limiter.py in _acquire_request_slot(self)
#     265     def _acquire_request_slot(self):
#     266         for wait in self._acquire_request_slot_gen():
# --> 267             self._sleep(wait)
#     268
#     269     def __call__(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/geopy/extra/rate_limiter.py in _sleep(self, seconds)
#     261     def _sleep(self, seconds):  # pragma: no cover
#     262         logger.debug(type(self).__name__ + " sleep(%r)", seconds)
# --> 263         sleep(seconds)
#     264
#     265     def _acquire_request_slot(self):
#
# KeyboardInterrupt:

# %%
print("Train DataFrame NaN Values:")
print(train_df[['좌표X', '좌표Y']].isna().sum())

# '위도', '경도'의 NaN 값 확인
print("Subway DataFrame NaN Values:")
print(subway_feature_df[['위도', '경도']].isna().sum())

# %%
print("Train Head DataFrame Columns:", train_df.columns)
print("Subway Feature Head DataFrame Columns:", subway_feature_df.columns)
# Out:
# Train Head DataFrame Columns: Index(['시군구', '번지', '본번', '부번', '아파트명', '전용면적(㎡)', '계약년월', '계약일', '층', '건축년도',
#        '도로명', '해제사유발생일', '등기신청일자', '거래유형', '중개사소재지', 'k-단지분류(아파트,주상복합등등)',
#        'k-전화번호', 'k-팩스번호', '단지소개기존clob', 'k-세대타입(분양형태)', 'k-관리방식', 'k-복도유형',
#        'k-난방방식', 'k-전체동수', 'k-전체세대수', 'k-건설사(시공사)', 'k-시행사', 'k-사용검사일-사용승인일',
#        'k-연면적', 'k-주거전용면적', 'k-관리비부과면적', 'k-전용면적별세대현황(60㎡이하)',
#        'k-전용면적별세대현황(60㎡~85㎡이하)', 'k-85㎡~135㎡이하', 'k-135㎡초과', 'k-홈페이지',
#        'k-등록일자', 'k-수정일자', '고용보험관리번호', '경비비관리형태', '세대전기계약방법', '청소비관리형태',
#        '건축면적', '주차대수', '기타/의무/임대/임의=1/2/3/4', '단지승인일', '사용허가여부', '관리비 업로드',
#        '좌표X', '좌표Y', '단지신청일', 'target'],
#       dtype='object')
# Subway Feature Head DataFrame Columns: Index(['역사_ID', '역사명', '호선', '위도', '경도'], dtype='object')

# %%
# 각 데이터프레임의 헤드를 새로운 CSV 파일로 저장
train_head = train_df.head()
subway_feature_head = subway_feature_df.head()

train_head.to_csv('/content/drive/MyDrive/ML4_adv/train_head.csv', index=False)
subway_feature_head.to_csv('/content/drive/MyDrive/ML4_adv/subway_feature_head.csv', index=False)

# %%
# Haversine 거리 계산 함수
def haversine(lat1, lon1, lat2, lon2):
    R = 6371.0  # 지구의 반경 (km)
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat / 2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = R * c
    return distance


# 가장 가까운 지하철역을 찾는 함수
def find_nearest_station(x, y, subway_df):
    min_distance = float('inf')
    nearest_station = None
    for _, row in subway_df.iterrows():
        distance = haversine(y, x, row['위도'], row['경도'])
        if distance < min_distance:
            min_distance = distance
            nearest_station = row['역사명']
    return nearest_station

# train 데이터에 가장 가까운 지하철역을 추가합니다
train_df['nearest_station'] = train_df.apply(lambda row: find_nearest_station(row['좌표X'], row['좌표Y'], subway_feature_df), axis=1)

# 결과를 출력합니다
print(train_df)

# 병합된 데이터프레임을 저장합니다
train_df.to_csv('/content/drive/MyDrive/ML4_adv/merged_train_with_nearest_station.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-f4171127b03b> in <cell line: 24>()
#      22
#      23 # train 데이터에 가장 가까운 지하철역을 추가합니다
# ---> 24 train_df['nearest_station'] = train_df.apply(lambda row: find_nearest_station(row['좌표X'], row['좌표Y'], subway_feature_df), axis=1)
#      25
#      26 # 결과를 출력합니다
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9421             kwargs=kwargs,
#    9422         )
# -> 9423         return op.apply().__finalize__(self, method="apply")
#    9424
#    9425     def applymap(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     676             return self.apply_raw()
#     677
# --> 678         return self.apply_standard()
#     679
#     680     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     796
#     797     def apply_standard(self):
# --> 798         results, res_index = self.apply_series_generator()
#     799
#     800         # wrap results
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     812             for i, v in enumerate(series_gen):
#     813                 # ignore SettingWithCopy here in case the user mutates
# --> 814                 results[i] = self.f(v)
#     815                 if isinstance(results[i], ABCSeries):
#     816                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-26-f4171127b03b> in <lambda>(row)
#      22
#      23 # train 데이터에 가장 가까운 지하철역을 추가합니다
# ---> 24 train_df['nearest_station'] = train_df.apply(lambda row: find_nearest_station(row['좌표X'], row['좌표Y'], subway_feature_df), axis=1)
#      25
#      26 # 결과를 출력합니다
#
# <ipython-input-26-f4171127b03b> in find_nearest_station(x, y, subway_df)
#      15     nearest_station = None
#      16     for _, row in subway_df.iterrows():
# ---> 17         distance = haversine(y, x, row['위도'], row['경도'])
#      18         if distance < min_distance:
#      19             min_distance = distance
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1117
#    1118         if is_integer(loc):
# -> 1119             return self._values[loc]
#    1120
#    1121         if isinstance(self.index, MultiIndex):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _values(self)
#     748
#     749         """
# --> 750         return self._mgr.internal_values()
#     751
#     752     @property
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in internal_values(self)
#    2009         return self._block.external_values()
#    2010
# -> 2011     def internal_values(self):
#    2012         """The array that Series._values returns"""
#    2013         return self._block.values
#
# KeyboardInterrupt:

# %%
# KDTree에 사용할 좌표를 준비합니다
subway_coords = subway_feature_df[['위도', '경도']].values
subway_tree = KDTree(subway_coords)

# NaN 값을 처리합니다 (예: 평균 값으로 대체하거나 제거)
train_df = train_df.dropna(subset=['좌표X', '좌표Y'])
subway_df = subway_feature_df.dropna(subset=['위도', '경도'])
# 가장 가까운 지하철역을 찾는 함수
def find_nearest_station_kdtree(x, y, subway_df, subway_tree):
    distance, index = subway_tree.query([y, x])
    nearest_station = subway_df.iloc[index]['역사명']
    return nearest_station

# train 데이터에 가장 가까운 지하철역을 추가합니다
train_df['nearest_station'] = train_df.apply(lambda row: find_nearest_station_kdtree(row['좌표X'], row['좌표Y'], subway_feature_df, subway_tree), axis=1)

# 결과를 출력합니다
print(train_df)

# 병합된 데이터프레임을 저장합니다
train_df.to_csv('/content/drive/MyDrive/ML4_adv/merged_train_with_nearest_station.csv', index=False)
# Out:
#                    시군구     번지     본번    부번    아파트명  전용면적(㎡)    계약년월  계약일   층  \
# 0        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성    79.97  201712    8   3
# 1        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성    79.97  201712   22   4
# 2        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성    54.98  201712   28   5
# 3        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성    79.97  201801    3   4
# 4        서울특별시 강남구 개포동  658-1  658.0   1.0  개포6차우성    79.97  201801    8   2
# ...                ...    ...    ...   ...     ...      ...     ...  ...  ..
# 1118817  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대    59.94  200707   12  11
# 1118818  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대    59.94  200708   25  10
# 1118819  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대    84.83  200708   31  20
# 1118820  서울특별시 은평구 구산동    382  382.0   0.0    갈현현대    84.83  200709   15   8
# 1118821   서울특별시 중구 묵정동  11-67   11.0  67.0      묵정    52.46  200701   10   5
#
#          건축년도  ...   주차대수  기타/의무/임대/임의=1/2/3/4                  단지승인일 사용허가여부  \
# 0        1987  ...  262.0                   임의  2022-11-17 13:00:29.0      Y
# 1        1987  ...  262.0                   임의  2022-11-17 13:00:29.0      Y
# 2        1987  ...  262.0                   임의  2022-11-17 13:00:29.0      Y
# 3        1987  ...  262.0                   임의  2022-11-17 13:00:29.0      Y
# 4        1987  ...  262.0                   임의  2022-11-17 13:00:29.0      Y
# ...       ...  ...    ...                  ...                    ...    ...
# 1118817  1998  ...  366.0                   의무  2013-06-04 16:18:51.0      Y
# 1118818  1998  ...  366.0                   의무  2013-06-04 16:18:51.0      Y
# 1118819  1998  ...  366.0                   의무  2013-06-04 16:18:51.0      Y
# 1118820  1998  ...  366.0                   의무  2013-06-04 16:18:51.0      Y
# 1118821  1981  ...   45.0                   임의  2020-07-10 00:00:00.0      Y
#
#         관리비 업로드         좌표X        좌표Y                  단지신청일  target  \
# 0             N  127.057210  37.476763  2022-11-17 10:19:06.0  124000
# 1             N  127.057210  37.476763  2022-11-17 10:19:06.0  123500
# 2             N  127.057210  37.476763  2022-11-17 10:19:06.0   91500
# 3             N  127.057210  37.476763  2022-11-17 10:19:06.0  130000
# 4             N  127.057210  37.476763  2022-11-17 10:19:06.0  117000
# ...         ...         ...        ...                    ...     ...
# 1118817       N  126.905638  37.612962  2013-03-07 09:46:27.0   20000
# 1118818       N  126.905638  37.612962  2013-03-07 09:46:27.0   20000
# 1118819       N  126.905638  37.612962  2013-03-07 09:46:27.0   28000
# 1118820       N  126.905638  37.612962  2013-03-07 09:46:27.0   29000
# 1118821       Y  127.000071  37.560706  2017-09-05 20:06:39.0   13250
#
#         nearest_station
# 0                    구룡
# 1                    구룡
# 2                    구룡
# 3                    구룡
# 4                    구룡
# ...                 ...
# 1118817              구산
# 1118818              구산
# 1118819              구산
# 1118820              구산
# 1118821            동대입구
#
# [249152 rows x 53 columns]
